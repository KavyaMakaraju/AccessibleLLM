# %%
pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.3-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 40.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2024.2.2)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.3

# %%
pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
# !pip install --upgrade pydub
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)

# %%
import os
import csv
import speech_recognition as sr
from pydub import AudioSegment
from pydub.playback import play

def transcribe_whispering_audio(audio_file):
    # Convert MP3 to WAV
    wav_file = audio_file[:-4] + ".wav"  # Change file extension to .wav
    sound = AudioSegment.from_mp3(audio_file)


    sound.export(wav_file, format="wav")


    recognizer = sr.Recognizer()


    recognizer.energy_threshold = 100

    with sr.AudioFile(wav_file) as source:
        audio = recognizer.record(source)

    try:
        text = recognizer.recognize_google(audio)
        os.remove(wav_file)
        return text.strip(), True
    except sr.UnknownValueError:
        print(f"Error: Could not understand audio file {audio_file}")
        os.remove(wav_file)
        return "", False
    except sr.RequestError as e:
        print(f"Error: Could not request results from Google Speech Recognition service; {e}")
        os.remove(wav_file)
        return "", False

def evaluate_accuracy(audio_folder, csv_file):
    total_files = 0
    correctly_transcribed = 0
    false_positives = 0
    false_negatives = 0
    with open(csv_file, 'r') as file:
        reader = csv.reader(file)
        next(reader)
        for row in reader:
            audio_file = os.path.join(audio_folder, row[0])
            ground_truth_caption = row[1]
            generated_caption, success = transcribe_whispering_audio(audio_file)
            if success:
                total_files += 1
                if ground_truth_caption.lower() == generated_caption.lower():
                    correctly_transcribed += 1
                else:
                    false_negatives += 1
                    print(f"Audio file: {row[0]}, Ground Truth: {ground_truth_caption}, Generated: {generated_caption}")
            else:
                false_positives += 1
                print(f"Failed to transcribe audio file: {row[0]}")

    accuracy = (correctly_transcribed / total_files) * 100 if total_files > 0 else 0
    precision = correctly_transcribed / (correctly_transcribed + false_positives) if (correctly_transcribed + false_positives) > 0 else 0
    recall = correctly_transcribed / (correctly_transcribed + false_negatives) if (correctly_transcribed + false_negatives) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    print(f"Total files: {total_files}, Correctly transcribed: {correctly_transcribed}")
    print(f"Accuracy: {accuracy:.2f}%")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 Score: {f1_score:.2f}")

def main():
    dataset_folder = "/content/drive/MyDrive/speech-to-text-dataset"
    audio_folder = os.path.join(dataset_folder, "cv-other-train")
    csv_file = os.path.join(dataset_folder, "cv-other-train.csv")
    evaluate_accuracy(audio_folder, csv_file)

main()
# Out:
# Audio file: sample-000000.mp3, Ground Truth: he had to spit some tobacco out of his mouth, Generated: you have to spend some tobacco out of his mouth
# Audio file: sample-000001.mp3, Ground Truth: it took her a while to get used to it, Generated: Dakota oil and get you stick
# Error: Could not understand audio file /content/drive/MyDrive/speech-to-text-dataset/cv-other-train/sample-000003.mp3
# Failed to transcribe audio file: sample-000003.mp3
# Audio file: sample-000005.mp3, Ground Truth: we're a couple of financial wizards, Generated: where a couple of financial Wizards
# Audio file: sample-000006.mp3, Ground Truth: better hurry and shave, Generated: Veterinary and shave
# Audio file: sample-000008.mp3, Ground Truth: you called that number not ten minutes ago, Generated: you called that number not 10 minutes ago
# Audio file: sample-000010.mp3, Ground Truth: those women are all card sharks don't be fooled, Generated: those women are all card sharks don't be foe
# Audio file: sample-000011.mp3, Ground Truth: wish i had a million dollars, Generated: wish I had a million dollar
# Audio file: sample-000013.mp3, Ground Truth: i haven't any hard feelings, Generated: I have any hard feelings
# Audio file: sample-000014.mp3, Ground Truth: there's that reprieve if they ever find out, Generated: girls that reply if they ever find
# Error: Could not understand audio file /content/drive/MyDrive/speech-to-text-dataset/cv-other-train/sample-000017.mp3
# Failed to transcribe audio file: sample-000017.mp3
# Audio file: sample-000018.mp3, Ground Truth: what is an alchemist he asked finally, Generated: what is an alchemist he asked fin
# Audio file: sample-000023.mp3, Ground Truth: look how flexible these athletes are, Generated: look how flexible this athletes are
# Audio file: sample-000024.mp3, Ground Truth: book me and my grandparents a restaurant in saint helens south dakota, Generated: book me my grandparents a restaurant in St Helens South
# Audio file: sample-000025.mp3, Ground Truth: the book was written in spanish, Generated: the book was written
# Audio file: sample-000027.mp3, Ground Truth: ii was terribly worried, Generated: I I was terribly worried
# Audio file: sample-000030.mp3, Ground Truth: i think its too overwhelming to introduce two complex tools that basically do the same things, Generated: I think it's too overwhelming to introduce two complex tools that basically do the same things
# Audio file: sample-000031.mp3, Ground Truth: before he gets through tonight he'll ruin us all, Generated: before it gets through tonight he'll ruin us all
# Audio file: sample-000032.mp3, Ground Truth: any dope yet on how he got out, Generated: I need a job yet on how he got out
# Audio file: sample-000035.mp3, Ground Truth: what're you trying to do, Generated: what are you trying to do
# Audio file: sample-000040.mp3, Ground Truth: seventeen minutes later she was in the water and nearly drowned, Generated: 17 minutes later she was in the water and nearly drowned
# Audio file: sample-000041.mp3, Ground Truth: with a bag of marshmallows, Generated: play the bag of marshmallows
# Audio file: sample-000043.mp3, Ground Truth: you guys at mozilla should really include every letter of the alphabet into this, Generated: you guys have Mozilla should really include every letter of the alphabet into this
# Audio file: sample-000044.mp3, Ground Truth: is it cold in vigus tennessee, Generated: is it cold in Vegas Tennessee
# Audio file: sample-000049.mp3, Ground Truth: we've been fed baloney so long we're getting used to it, Generated: we've been fed bologna so long we are getting used to it
# Audio file: sample-000050.mp3, Ground Truth: your luck's not with you now, Generated: your locks not with you now
# Audio file: sample-000051.mp3, Ground Truth: who do you think writes them, Generated: who do you think trust them
# Audio file: sample-000052.mp3, Ground Truth: i'll discuss the techniques i use to wrangle my grammars, Generated: I'll discuss the techniques are used to Wrangle my Graham
# Audio file: sample-000053.mp3, Ground Truth: underneath the ground was a world unknown to any human, Generated: underneath the ground was a world on now human
# Audio file: sample-000055.mp3, Ground Truth: burning fridges televisions and washing machines are not as unusual as one might think, Generated: burning fridges television and washing machine are not as unusual as one might
# Audio file: sample-000056.mp3, Ground Truth: everyone has once heard of the chickeneggproblem, Generated: everyone has once heard of the chicken egg problem
# Audio file: sample-000057.mp3, Ground Truth: alchemy is a serious discipline, Generated: ultimate is a serious
# Audio file: sample-000062.mp3, Ground Truth: don't get technical at a time like this, Generated: don't get technology
# Audio file: sample-000066.mp3, Ground Truth: he was already re accustomed to desert's silence, Generated: he was already re-access themed to Desert
# Audio file: sample-000068.mp3, Ground Truth: maybe the alchemist has never been in love the boy thought, Generated: maybe the Alchemists has never been in love with boyfriend
# Audio file: sample-000070.mp3, Ground Truth: about time one of you lunkheads said it, Generated: about time one of your lunch had said it
# Audio file: sample-000071.mp3, Ground Truth: is it possible to see the italian job at malco theatres, Generated: it is possible to see the Italian job at Malco Theaters
# Audio file: sample-000072.mp3, Ground Truth: towering buildings form the quintessential skyline, Generated: towering buildings from the quintessential Skyline
# Audio file: sample-000074.mp3, Ground Truth: please search the songs for the deaf video game, Generated: search the song for the day
# Audio file: sample-000078.mp3, Ground Truth: book a reservation for a pub serving croquembouche, Generated: book a reservation for Pub serving bush
# Audio file: sample-000079.mp3, Ground Truth: but you want to know something, Generated: do you want to know something
# Audio file: sample-000080.mp3, Ground Truth: a friend had told the boy about the shop and he had taken his sheep there, Generated: a friend had told the boy about the shop and he had taken his shift there
# Audio file: sample-000081.mp3, Ground Truth: he wants to get jill started in the research business, Generated: he want to get Jill started in the recent businesses
# Audio file: sample-000084.mp3, Ground Truth: i'm interested only in the present, Generated: I'm interested only the Pres
# Error: Could not understand audio file /content/drive/MyDrive/speech-to-text-dataset/cv-other-train/sample-000085.mp3
# Failed to transcribe audio file: sample-000085.mp3
# Audio file: sample-000086.mp3, Ground Truth: i think somebody stole one of his crown jewels, Generated: I think somebody stole one of his crown
# Error: Could not understand audio file /content/drive/MyDrive/speech-to-text-dataset/cv-other-train/sample-000088.mp3
# Failed to transcribe audio file: sample-000088.mp3
# Audio file: sample-000089.mp3, Ground Truth: the pink love heart keyring glowed, Generated: the pink law of heart key ring
# Audio file: sample-000091.mp3, Ground Truth: the other son was a poet and delighted all of rome with his beautiful verses, Generated: the other son was a poet and delighted all of them with this beautiful verses
# Audio file: sample-000095.mp3, Ground Truth: i guess i was homesick, Generated: I guess it was homesick
# Audio file: sample-000097.mp3, Ground Truth: there was no justification provided, Generated: there was no justification
# Audio file: sample-000099.mp3, Ground Truth: a lantern lit up the trees, Generated: Palatine lit up the trees
# Audio file: sample-000101.mp3, Ground Truth: the boy didn't know what a person's destiny was, Generated: the boy didn't know what a person's destiny
# Audio file: sample-000102.mp3, Ground Truth: i learned the alchemist's secrets in my travels, Generated: I learned The Alchemist secrets in my travels
# Audio file: sample-000103.mp3, Ground Truth: tomorrow at this same time bring me a tenth of your flock, Generated: tomorrow at the same time bring me a 10th of your flock
# Audio file: sample-000106.mp3, Ground Truth: but horses tire bit by bit, Generated: but horses Tire Beats by bit
# Audio file: sample-000108.mp3, Ground Truth: they found all sorts of drugs at howard's house cocaine meth heroine, Generated: Define all sorts of drugs and Howard's house cocaine math
# Audio file: sample-000111.mp3, Ground Truth: give the current saga a  out of  points, Generated: give the current Saga for 6 poyntz
# Audio file: sample-000113.mp3, Ground Truth: one by one the campfires were extinguished and the oasis fell as quiet as the desert, Generated: 1 x 1 the campfires were extinguished and the Oasis fell as quiet as the desert
# Audio file: sample-000115.mp3, Ground Truth: add an album from thomen stauch to my rock this playlist, Generated: add an album from someone else to my office playlist
# Audio file: sample-000118.mp3, Ground Truth: they reached the center of a large plaza where the market was held, Generated: there is the center of the large Plaza when the market was held
# Audio file: sample-000119.mp3, Ground Truth: you and i aren't like hassan that rich merchant, Generated: you and I aren't like her son that rich Merchant
# Audio file: sample-000124.mp3, Ground Truth: get out of here, Generated: get out
# Audio file: sample-000127.mp3, Ground Truth: smoking cigarettes during pregnancy increases the risk of the baby also becoming addicted one day, Generated: smoking cigarettes during pregnancy increases the risk of the baby also becoming addicting one day
# Audio file: sample-000131.mp3, Ground Truth: ii was terribly worried, Generated: I I was terribly worried
# Audio file: sample-000132.mp3, Ground Truth: he could see that the old man wanted to know more about his life, Generated: you could see that the old man wanted to know more about his life
# Audio file: sample-000134.mp3, Ground Truth: can you see what is beyond the golden birches , Generated: can you see what is beyond the golden purchase
# Audio file: sample-000135.mp3, Ground Truth: now look what you've done, Generated: now look what you have done
# Audio file: sample-000139.mp3, Ground Truth: eating oat flakes for breakfast combined with hard training will hopefully give me a sixpack stomach soon enough, Generated: eating old flakes for first combined with heart training will hopefully give me a six-pack stomach soon enough
# Audio file: sample-000141.mp3, Ground Truth: this is jon davis, Generated: this is John Davis
# Audio file: sample-000145.mp3, Ground Truth: the electrician looked puzzled, Generated: the electrician look puzzled
# Error: Could not understand audio file /content/drive/MyDrive/speech-to-text-dataset/cv-other-train/sample-000148.mp3
# Failed to transcribe audio file: sample-000148.mp3
# Audio file: sample-000149.mp3, Ground Truth: if we actually do want it solved it will be, Generated: if we actually do one it's solved it will be
# Audio file: sample-000151.mp3, Ground Truth: i was right there and saw it with my own eyes, Generated: I was right there and I saw it with my own eyes
# Audio file: sample-000152.mp3, Ground Truth: i'd like to build a display case for the crystal the boy said to the merchant, Generated: I'd like to build a display case for the crystal boy said to the merchant
# Audio file: sample-000153.mp3, Ground Truth: i'm not hiding anything the boy answered, Generated: I'm not hiding anything the boy
# Audio file: sample-000155.mp3, Ground Truth: the internet is built upon many protocols which compliment each other perfectly, Generated: the internet is built upon many protocols which complement each other perfectly
# Audio file: sample-000158.mp3, Ground Truth: a gorilla had stepped into the trap and was now transported to the zoo, Generated: go ahead stepped into the Trap and was now transported to the zoo
# Audio file: sample-000159.mp3, Ground Truth: so what do you want of me the sun asked, Generated: so what do you want of me
# Audio file: sample-000163.mp3, Ground Truth: our mortgage is in arrears, Generated: I'm okay she's in a Wheels
# Audio file: sample-000165.mp3, Ground Truth: the desert takes our men from us and they don't always return she said, Generated: Adele takes a Roman from us and they don't always return what she said
# Audio file: sample-000168.mp3, Ground Truth: they reached the center of a large plaza where the market was held, Generated: they reach the center of a large plaza where the market was held
# Audio file: sample-000169.mp3, Ground Truth: it was a litmus test, Generated: that was the name of the test
# Audio file: sample-000170.mp3, Ground Truth: the publicity's the main thing, Generated: the publicity is the main
# Audio file: sample-000174.mp3, Ground Truth: the boy prodded them one by one with his crook calling each by name, Generated: devoid protein one by one with his crook calling each by name
# Audio file: sample-000175.mp3, Ground Truth: you ain't gonna get me to stay here, Generated: you ain't going to get me to stay here
# Audio file: sample-000178.mp3, Ground Truth: there's life here the boy said to the alchemist, Generated: there's life here the boy said The Alchemist
# Audio file: sample-000179.mp3, Ground Truth: i am definitely open to the idea because ive always wanted to work as a small business owner, Generated: I'm definitely open to the idea because I've always wanted to work as a small business owner
# Audio file: sample-000180.mp3, Ground Truth: cover up that transmitter, Generated: convert the transmitter
# Audio file: sample-000183.mp3, Ground Truth: i missed you and i couldnt call you but i tried, Generated: I miss you and I couldn't call you but I tried
# Audio file: sample-000188.mp3, Ground Truth: heehaw and merry christmas, Generated: Hee Haw and Merry Christmas
# Audio file: sample-000190.mp3, Ground Truth: the boy continued to listen to his heart as they crossed the desert, Generated: the boy continued to listen to his heart as they cross the desert
# Audio file: sample-000192.mp3, Ground Truth: the reader just needs to know what it does, Generated: the Rita just needs to know what it does
# Audio file: sample-000193.mp3, Ground Truth: he had assumed he would soon return to his sheep, Generated: he had a so he would send picture to his sheep
# Audio file: sample-000194.mp3, Ground Truth: why are the weights computed this way, Generated: why are the weights computer this way
# Audio file: sample-000196.mp3, Ground Truth: but that's why you created the game in the first place the boy answered, Generated: but that's why you created the game in the first place if the boy answered
# Audio file: sample-000197.mp3, Ground Truth: the camel driver though seemed not to be very concerned with the threat of war, Generated: the camel driver does seem not very concerned with the threat of War
# Audio file: sample-000199.mp3, Ground Truth: after that foul the whole stadium was yelling angry things, Generated: after that file the whole stadium was yelling angry things
# Audio file: sample-000200.mp3, Ground Truth: you can't stop for a thing now, Generated: can't stop for think now
# Audio file: sample-000201.mp3, Ground Truth: absolutely despicable that gingerbread men are forced to live in houses made of their own flesh, Generated: absolutely despicable that gingerbread man on First and houses made of Their Own
# Audio file: sample-000203.mp3, Ground Truth: it's common to run into problems so read the instructions carefully, Generated: it's common to run into problems so read the instructions care
# Audio file: sample-000204.mp3, Ground Truth: it left a greenish streak that glowed for some seconds, Generated: it left a greenish streak that closed for some seconds
# Audio file: sample-000207.mp3, Ground Truth: there was no excuse for goodman to fly off the handle, Generated: Samsung excuse for Goodman to fly off the handle
# Audio file: sample-000208.mp3, Ground Truth: ogilvy told him everything that he had seen, Generated: agility told him everything that he had
# Audio file: sample-000210.mp3, Ground Truth: first she was moaning then coughing and eventually her ventilation collapsed, Generated: first she was morning then cotton and eventually going to insulation coll
# Audio file: sample-000211.mp3, Ground Truth: this convention's gonna cost plenty, Generated: is conventions going to cost plenty
# Audio file: sample-000213.mp3, Ground Truth: the tin was made from aluminium, Generated: the tin was made from aluminum
# Audio file: sample-000214.mp3, Ground Truth: the pink love heart keyring glowed, Generated: Bank of heart hearing globe
# Audio file: sample-000216.mp3, Ground Truth: ask the owner of that stall how much the sword costs he said to his friend, Generated: Osceola how much the sword costs you said to his friend
# Audio file: sample-000217.mp3, Ground Truth: yet it was a little too large for assurance, Generated: yes it was a little too large for Assurance
# Audio file: sample-000222.mp3, Ground Truth: he gave me his word of honor, Generated: he gave me his word of hon
# Audio file: sample-000223.mp3, Ground Truth: these families have children, Generated: these families have
# Audio file: sample-000224.mp3, Ground Truth: affirmative a breaching charge is available, Generated: affirmative preaching church is available
# Audio file: sample-000227.mp3, Ground Truth: there's just so much a body can do, Generated: there's just so much about you can do
# Audio file: sample-000228.mp3, Ground Truth: a card hanging in the doorway announced that several languages were spoken in the shop, Generated: a cartoon in the doorway announced that several languages were spoken in the shop
# Audio file: sample-000230.mp3, Ground Truth: its just a few blocks to the north, Generated: it's just a few blocks to the
# Audio file: sample-000233.mp3, Ground Truth: was it my fault, Generated: was it my
# Audio file: sample-000235.mp3, Ground Truth: mohammed is a wonderful guitar player, Generated: Muhammad is a wonderful guitar player
# Audio file: sample-000236.mp3, Ground Truth: the book that most interested the boy told the stories of the famous alchemists, Generated: the book that most interested the boy told the stories of the famous Alchemist
# Audio file: sample-000240.mp3, Ground Truth: this is for the boy, Generated: distance from
# Audio file: sample-000242.mp3, Ground Truth: why shouldn't i make father my beneficiary, Generated: why shouldn't I thought my beneficiary
# Audio file: sample-000244.mp3, Ground Truth: i owe everything to corey brown, Generated: oh everything to Cody Brown
# Audio file: sample-000245.mp3, Ground Truth: he only lost three buttons off his vest, Generated: yearly lost three buttons office vest
# Audio file: sample-000246.mp3, Ground Truth: my boyfriend caught two huge fish yesterday evening, Generated: my boyfriend called two huge fish yesterday evening
# Audio file: sample-000247.mp3, Ground Truth: in a cinematic ropedown maneuver the special forces overwhelmed the criminals, Generated: in a cinematic wrote down maneuver the Special Forces overwhelmed the criminals
# Audio file: sample-000250.mp3, Ground Truth: the boy closed his book, Generated: the boy closed his
# Total files: 246, Correctly transcribed: 125
# Accuracy: 50.81%
# Precision: 0.96
# Recall: 0.51
# F1 Score: 0.66
